# %% [markdown]
# # Sets

# %%
# -> Set is a collection of Unique elements
# -> sets are unordered
# -> python 3.7 -insertion ordered we can iterate
# -> sets can store all immutable
# -> sets cant store mutables

# %%
a={}
print(type(a))
# Out:
# <class 'dict'>

# %%
a=set()

# %%
type(a)
# Out:
# set

# %%
# no duplicate

# %%
a={1,2,3,4}

# %%
print(a,type(a))
# Out:
# {1, 2, 3, 4} <class 'set'>

# %%
list1=[1,2,3,13,2]
print(len(set(list1)))
# Out:
# 4

# %%
# sets are unordered

# %%
a={1,2,3,4}
a[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 a={1,2,3,4}
# ----> 2 a[0]
#
# TypeError: 'set' object is not subscriptable

# %%
a[0:3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 a[0:3]
#
# TypeError: 'set' object is not subscriptable

# %%
for i in a:
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
a={5,2,3,1}
print(a)
# Out:
# {1, 2, 3, 5}

# %%
for i in a:
    print(i)
# Out:
# 1
# 2
# 3
# 5

# %%
#immutable

# %%
set1={1,2,3,{4,5}}
print(set1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 set1={1,2,3,{4,5}}
#       2 print(set1)
#
# TypeError: unhashable type: 'set'

# %%
set1={1,2,3,(4,5)}

# %%
print(set1)
# Out:
# {3, 1, (4, 5), 2}

# %%
for i in set1:
    print(i)
# Out:
# 3
# 1
# (4, 5)
# 2

# %%
# Set methods

# %%
s={1,2,3}

# %%
print(s)
# Out:
# {1, 2, 3}

# %%
s.add(4)

# %%
s
# Out:
# {1, 2, 3, 4}

# %%
# Remove element

# %%
s.remove(3)
print(s)
# Out:
# {1, 2, 4}

# %%
s={1,2,3,4}
a=s.pop()
print(s)
# Out:
# {2, 3, 4}

# %%
a
# Out:
# 1

# %%
# add
s={1,2,3,4,5}
s.add(5,6)
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[133], line 3
#       1 # add
#       2 s={1,2,3,4,5}
# ----> 3 s.add(5,6)
#       4 print(s)
#
# TypeError: set.add() takes exactly one argument (2 given)

# %%
## update
s={1,2,3,4}
s.update((5,6,7))
s
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
# write a function to take a string as input, print the number of unique character

# %%
a=set([1,2,3,1])
a
# Out:
# {1, 2, 3}

# %%
set("Jalaj")
# Out:
# {'J', 'a', 'j', 'l'}

# %%
# set operations

# %%
s1={1,2,3}
s2={2,5,3,4}
s1.intersection(s2)
# Out:
# {2, 3}

# %%
s2.intersection(s1)
# Out:
# {2, 3}

# %%
s2.intersection(s2)
# Out:
# {2, 3, 4, 5}

# %%
# intersection shortcut
s1&s2
# Out:
# {2, 3}

# %%
# UNION  - contains all elements from A and B
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5}

# %%
s3={9,8}
s1.union(s2).union(s3)
# Out:
# {1, 2, 3, 4, 5, 8, 9}

# %%
# Union shortcut

# %%
s1|s2 #-> pipe key
# Out:
# {1, 2, 3, 4, 5}

# %%
s2
# Out:
# {2, 3, 4, 5}

# %%
# difference

# %%
s1={1,2,3}
s2={2,5,3,4}
s1.difference(s2)
# Out:
# {1}

# %%
s2.difference(s1)
# Out:
# {4, 5}

# %%
# Differnce shortcut

# %%
s1-s2
# Out:
# {1}

# %%
s2-s1
# Out:
# {4, 5}

# %%
# symmetric_difference -> A and B except common elements

# %%
s1={1,2,3}
s2={2,5,3,4}

# %%
s2.symmetric_difference(s1)
# Out:
# {1, 4, 5}

# %%
s1.symmetric_difference(s2)
# Out:
# {1, 4, 5}

# %%
# symmetric_difference shortcut

# %%
s1^s2
# Out:
# {1, 4, 5}

# %%
d=set()
type(d)
# Out:
# set

# %%
s={{1,2,3,4,5}}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[219], line 1
# ----> 1 s={{1,2,3,4,5}}
#
# TypeError: unhashable type: 'set'

# %%
a={1,2,3}
b={1,2}

# %%
print(b-a)
# Out:
# set()

# %%
a={1,2,3}
b={1,2}

# %%
a-b
# Out:
# {3}

# %%
s1
# Out:
# {1, 2, 3}

# %%
s2
# Out:
# {2, 3, 4, 5}

# %%
s1&s2-s2
# Out:
# set()
